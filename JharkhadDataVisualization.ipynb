# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pwd
# Out:
# 'C:\\Users\\Subhajit'

# %%
data=pd.read_csv('C:\\Users\\Subhajit\\Covid19India.csv')
data
# Out:
#         Unnamed: 0  Num Cases Date Announced Age Bracket Gender  \
# 0                0        1.0     30/01/2020          20      F
# 1                1        1.0     02/02/2020         NaN    NaN
# 2                2        1.0     03/02/2020         NaN    NaN
# 3                3        1.0     02/03/2020          45      M
# 4                4        1.0     02/03/2020          24      M
# ...            ...        ...            ...         ...    ...
# 353028       26620       29.0     08/10/2020         NaN    NaN
# 353029       26621       10.0     08/10/2020         NaN    NaN
# 353030       26622       -8.0     08/10/2020         NaN    NaN
# 353031       26623        8.0     08/10/2020         NaN    NaN
# 353032       26624      -27.0     08/10/2020         NaN    NaN
#
#                    Detected City Detected District    Detected State  \
# 0                       Thrissur          Thrissur            Kerala
# ...

# %%
dt=pd.read_csv('C:\\Users\\Subhajit\\covid191.csv')
dt
dt.plot.bar()

# %%
dt.index
# Out:
# RangeIndex(start=0, stop=230, step=1)

# %%
dt.columns
# Out:
# Index(['Date', 'Active Cases'], dtype='object')

# %%
dt
# Out:
#            Date  Active Cases
# 0    12-03-2020            71
# 1    13-03-2020            71
# 2    14-03-2020            72
# 3    15-03-2020            95
# 4    16-03-2020            99
# ..          ...           ...
# 225  23-10-2020        695509
# 226  24-10-2020        680680
# 227  25-10-2020        668154
# 228  26-10-2020        653717
# 229  27-10-2020        625857
#
# [230 rows x 2 columns]

# %%
dt.plot.bar()

# %%
dr=pd.read_csv('C:\\Users\\Subhajit\\covid192.csv')
dr
dr.plot.bar()
dr
# Out:
#   MONTH  CONFIRMED
# 0   JAN          1
# 1   FEB          2
# 2   MAR       1632
# 3   APR      33231
# 4   MAY     155783
# 5  JUNE     395146
# 6  JULY    1111273
# 7   AUG    1990885
# 8  SEPT    2622323
# 9   OCT    1338890

# %%
dc=pd.read_csv('C:\\Users\\Subhajit\\covid193.csv')
dc
# Out:
#   MONTH  TOTAL RECOVERED
# 0   JAN                0
# 1   FEB                3
# 2   MAR              147
# 3   APR             8909
# 4   MAY            82803
# 5  JUNE           255978
# 6  JULY           747698
# 7   AUG          1741832
# 8  SEPT          2431632
# 9   OCT          1522529

# %%
dr.plot.bar()

# %%
dd=pd.read_csv('C:\\Users\\Subhajit\\covid194.csv')
dd
# Out:
#   MONTH  TOTAL DECEASED
# 0   JAN               0
# 1   FEB               0
# 2   MAR              47
# 3   APR            1107
# 4   MAY            4252
# 5  JUNE           12005
# 6  JULY           19155
# 7   AUG           28879
# 8  SEPT           32677
# 9   OCT           17242

# %%
ct.plot.bar()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-e01ad1305021> in <module>
# ----> 1 ct.plot.bar()
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in bar(self, x, y, **kwargs)
#    1001             >>> ax = df.plot.bar(x='lifespan', rot=0)
#    1002         """
# -> 1003         return self(kind="bar", x=x, y=y, **kwargs)
#    1004
#    1005     def barh(self, x=None, y=None, **kwargs):
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     845                     data.columns = label_name
#     846
# --> 847         return plot_backend.plot(data, kind=kind, **kwargs)
#     848
#     849     __call__.__doc__ = __doc__
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
# ...

# %%
ct=pd.read_csv('C:\\Users\\Subhajit\\covid195.csv')
ct
# Out:
#            COUNTRY TOTAL CASES
# 0              USA     9175543
# 1            INDIA     8087494
# 2           BRAZIL     5474840
# 3           RUSSIA     1581693
# 4           FRANCE     1282769
# 5            SPAIN     1238922
# 6        ARGENTINA     1130533
# 7         COLOMBIA     1041935
# 8   UNITED KINGDOM      965340
# 9           MEXICO      906863
# 10           CHINA      85,915

# %%
ct
# Out:
#            COUNTRY TOTAL CASES
# 0              USA     9175543
# 1            INDIA     8087494
# 2           BRAZIL     5474840
# 3           RUSSIA     1581693
# 4           FRANCE     1282769
# 5            SPAIN     1238922
# 6        ARGENTINA     1130533
# 7         COLOMBIA     1041935
# 8   UNITED KINGDOM      965340
# 9           MEXICO      906863
# 10           CHINA      85,915

# %%
ca=pd.read_csv('C:\\Users\\Subhajit\\covid196.csv')
ca
ca.plot.bar()
ca
# Out:
#       COUNTRY  ACTIVE CASES
# 0         USA       2986891
# 1       INDIA        595066
# 2      BRAZIL        381681
# 3      RUSSIA        368351
# 4      FRANCE       1131462
# 5       ITALY        299191
# 6   ARGENTINA        169315
# 7    COLOMBIA         69308
# 8     GERMANY        146762
# 9      MEXICO        152915
# 10      CHINA           338

# %%
ca=pd.read_csv('C:\\Users\\Subhajit\\covid196.csv')
ca.plot.bar()
ca
# Out:
#       COUNTRY  ACTIVE CASES
# 0         USA       2986891
# 1       INDIA        595066
# 2      BRAZIL        381681
# 3      RUSSIA        368351
# 4      FRANCE       1131462
# 5       ITALY        299191
# 6   ARGENTINA        169315
# 7    COLOMBIA         69308
# 8     GERMANY        146762
# 9      MEXICO        152915
# 10      CHINA           338

# %%
ca=pd.read_csv('C:\\Users\\Subhajit\\covid196.csv')
ca
# Out:
#       COUNTRY  ACTIVE CASES
# 0         USA       2986891
# 1       INDIA        595066
# 2      BRAZIL        381681
# 3      RUSSIA        368351
# 4      FRANCE       1131462
# 5       ITALY        299191
# 6   ARGENTINA        169315
# 7    COLOMBIA         69308
# 8     GERMANY        146762
# 9      MEXICO        152915
# 10      CHINA           338

# %%
ca.plot.bar()

# %%
ct=pd.read_csv('C:\\Users\\Subhajit\\covid196.csv')
ct
# Out:
#       COUNTRY TOTAL CASES
# 0         USA     9175543
# 1       INDIA     8087494
# 2      BRAZIL     5474840
# 3      RUSSIA     1581693
# 4      FRANCE     1282769
# 5       ITALY     1238922
# 6   ARGENTINA     1130533
# 7    COLOMBIA     1041935
# 8     GERMANY      965340
# 9      MEXICO      906863
# 10      CHINA      85,915

# %%
cd=pd.read_csv('C:\\Users\\Subhajit\\covid197.csv')
cd
# Out:
#            COUNTRY TOTAL DEATHS
# 0              USA       233745
# 1            INDIA       121120
# 2           BRAZIL       158611
# 3           RUSSIA        27301
# 4           FRANCE        36020
# 5            SPAIN        35639
# 6        ARGENTINA        30071
# 7         COLOMBIA        30753
# 8   UNITED KINGDOM        45955
# 9           MEXICO        90309
# 10           CHINA        4,634

# %%
cr=pd.read_csv('C:\\Users\\Subhajit\\covid198.csv')
cr
# Out:
#       COUNTRY RECOVERED CASES
# 0         USA         5954907
# 1       INDIA         7371308
# 2      BRAZIL         4934548
# 3      RUSSIA         1186041
# 4      FRANCE          115287
# 5       ITALY          279282
# 6   ARGENTINA          931147
# 7    COLOMBIA          941874
# 8     GERMANY          339200
# 9      MEXICO          663639
# 10      CHINA          80,943

# %%
cd.plot.bar()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-5da222e8dee1> in <module>
# ----> 1 cd.plot.bar()
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in bar(self, x, y, **kwargs)
#    1001             >>> ax = df.plot.bar(x='lifespan', rot=0)
#    1002         """
# -> 1003         return self(kind="bar", x=x, y=y, **kwargs)
#    1004
#    1005     def barh(self, x=None, y=None, **kwargs):
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     845                     data.columns = label_name
#     846
# --> 847         return plot_backend.plot(data, kind=kind, **kwargs)
#     848
#     849     __call__.__doc__ = __doc__
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
# ...

# %%
st=pd.read_csv('C:\\Users\\Subhajit\\covid19s1.csv')
st
# Out:
#            DATE  TOTAL CASES
# 0    02-04-2020            1
# 1    03-04-2020            2
# 2    04-04-2020            2
# 3    05-04-2020            2
# 4    06-04-2020            3
# ..          ...          ...
# 206  25-10-2020        99428
# 207  26-10-2020        99686
# 208  27-10-2020        99906
# 209  28-10-2020       100569
# 210  29-10-2020       100964
#
# [211 rows x 2 columns]

# %%
st.plot.bar()

# %%
sr=pd.read_csv('C:\\Users\\Subhajit\\covid19sr.csv')
sr
# Out:
#            DATE  TOTAL RECOVERED
# 0    02-04-2020                0
# 1    03-04-2020                0
# 2    04-04-2020                0
# 3    05-04-2020                0
# 4    06-04-2020                0
# ..          ...              ...
# 206  25-10-2020            92598
# 207  26-10-2020            92976
# 208  27-10-2020            93368
# 209  28-10-2020            94326
# 210  29-10-2020            94787
#
# [211 rows x 2 columns]

# %%
sr.plot.bar()

# %%
sd=pd.read_csv('C:\\Users\\Subhajit\\covid19sd.csv')
sd
# Out:
#            DATE  TOTAL DEATHS
# 0    02-04-2020             0
# 1    03-04-2020             0
# 2    04-04-2020             0
# 3    05-04-2020             0
# 4    06-04-2020             0
# ..          ...           ...
# 206  25-10-2020           864
# 207  26-10-2020           866
# 208  27-10-2020           872
# 209  28-10-2020           880
# 210  29-10-2020           883
#
# [211 rows x 2 columns]

# %%
sd.plot.bar()

# %%
dt=pd.read_csv('C:\\Users\\Subhajit\\covid19dt.csv')
dt
# Out:
#                 DISTRICT  TOTAL CONFIRMED
# 0                 BOKARO             5306
# 1                 CHATRA             1299
# 2                DEOGHAR             3047
# 3                DHANBAD             6265
# 4                  DUMKA             1244
# 5         EAST SINGHBHUM            16172
# 6                 GARHWA             2471
# 7                GIRIDIH             3280
# 8                  GODDA             1916
# 9                  GUMLA             2035
# 10             HAZARIBAG             4008
# 11               JAMTARA             1042
# 12                KHUNTI             1920
# 13               KODERMA             3259
# 14               LATEHAR             1704
# 15             LOHARDAGA             1585
# 16                 PAKUR              866
# 17                PALAMU             3019
# 18               RAMGARH             3943
# 19                RANCHI            25413
# 20             SAHIBGANJ             1504
# ...

# %%
dt.plot.bar()

# %%
dt=pd.read_csv('C:\\Users\\Subhajit\\covid19dt.csv')
dt
# Out:
#                 DISTRICT  TOTAL CONFIRMED
# 0                 BOKARO             5306
# 1                 CHATRA             1299
# 2                DEOGHAR             3047
# 3                DHANBAD             6265
# 4                  DUMKA             1244
# 5         EAST SINGHBHUM            16172
# 6                 GARHWA             2471
# 7                GIRIDIH             3280
# 8                  GODDA             1916
# 9                  GUMLA             2035
# 10             HAZARIBAG             4008
# 11               JAMTARA             1042
# 12                KHUNTI             1920
# 13               KODERMA             3259
# 14               LATEHAR             1704
# 15             LOHARDAGA             1585
# 16                 PAKUR              866
# 17                PALAMU             3019
# 18               RAMGARH             3943
# 19                RANCHI            25413
# 20             SAHIBGANJ             1504
# ...

# %%
dr=pd.read_csv('C:\\Users\\Subhajit\\covid19dr.csv')
dr
# Out:
#                 DISTRICT  TOTAL RECOVERED
# 0                 BOKARO             4942
# 1                 CHATRA             1246
# 2                DEOGHAR             2920
# 3                DHANBAD             5725
# 4                  DUMKA             1144
# 5         EAST SINGHBHUM            14516
# 6                 GARHWA             2390
# 7                GIRIDIH             3197
# 8                  GODDA             1867
# 9                  GUMLA             1924
# 10             HAZARIBAG             3907
# 11               JAMTARA              943
# 12                KHUNTI             1805
# 13               KODERMA             3199
# 14               LATEHAR             1686
# 15             LOHARDAGA             1510
# 16                 PAKUR              810
# 17                PALAMU             2973
# 18               RAMGARH             3873
# 19                RANCHI            23505
# 20             SAHIBGANJ             1466
# ...

# %%
dr.plot.bar()

# %%
dd=pd.read_csv('C:\\Users\\Subhajit\\covid19dd.csv')
dd
# Out:
#                 DISTRICT  TOTAL DEATHS
# 0                 BOKARO            46
# 1                 CHATRA            10
# 2                DEOGHAR            19
# 3                DHANBAD            81
# 4                  DUMKA             9
# 5         EAST SINGHBHUM           333
# 6                 GARHWA            10
# 7                GIRIDIH            13
# 8                  GODDA             9
# 9                  GUMLA             2
# 10             HAZARIBAG            26
# 11               JAMTARA             2
# 12                KHUNTI             5
# 13               KODERMA            28
# 14               LATEHAR             5
# 15             LOHARDAGA             9
# 16                 PAKUR             2
# 17                PALAMU            15
# 18               RAMGARH            24
# 19                RANCHI           175
# 20             SAHIBGANJ             9
# 21  SAERAIKELA KHARSAWAN            11
# 22               SIMDEGA             4
# ...

# %%
dd.plot.bar()
